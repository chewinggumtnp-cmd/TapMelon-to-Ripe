# %% [markdown]
# <a href="https://colab.research.google.com/github/chewinggumtnp-cmd/TapMelon-to-Ripe/blob/main/requirements_txt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# streamlit
# streamlit-audiorecorder
# librosa
# tensorflow
# # หากใช้ไลบรารีอื่น เช่น scikit-learn ก็เพิ่มเข้าไปด้วย
